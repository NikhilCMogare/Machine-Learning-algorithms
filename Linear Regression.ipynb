# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Creating a random numpy array using np.random.randint() fn for area and price

area = np.random.randint(500, 900, 40)
price = np.random.randint(30, 99, 40)

# %%
area
# Out:
# array([822, 625, 611, 693, 883, 898, 681, 566, 689, 562, 775, 726, 552,
#        602, 855, 863, 636, 864, 863, 680, 789, 756, 562, 881, 879, 832,
#        634, 631, 698, 767, 852, 750, 651, 685, 711, 663, 602, 715, 643,
#        553])

# %%
price
# Out:
# array([45, 68, 77, 97, 40, 54, 64, 39, 48, 41, 62, 43, 58, 45, 54, 95, 39,
#        57, 37, 74, 75, 71, 94, 34, 53, 79, 59, 93, 83, 67, 64, 65, 37, 45,
#        91, 57, 92, 68, 94, 91])

# %%
# Sorting both the array in ascending order

area.sort()
price.sort()

# %%
area
# Out:
# array([552, 553, 562, 562, 566, 602, 602, 611, 625, 631, 634, 636, 643,
#        651, 663, 680, 681, 685, 689, 693, 698, 711, 715, 726, 750, 756,
#        767, 775, 789, 822, 832, 852, 855, 863, 863, 864, 879, 881, 883,
#        898])

# %%
price
# Out:
# array([34, 37, 37, 39, 39, 40, 41, 43, 45, 45, 45, 48, 53, 54, 54, 57, 57,
#        58, 59, 62, 64, 64, 65, 67, 68, 68, 71, 74, 75, 77, 79, 83, 91, 91,
#        92, 93, 94, 94, 95, 97])

# %%
# Plotting both the array in the form of scatter plot.

# %matplotlib inline
plt.title("Area vs Price")
plt.xlabel("Area in SqFt")
plt.ylabel("Price in Lakh")
plt.scatter(area, price, marker="*", c="r")
plt.show()
plt.savefig("linear data example.png")

# %%
# %matplotlib inline
plt.title("Area vs Price")
plt.xlabel("Area in SqFt")
plt.ylabel("Price in Lakh")
plt.plot(area, price, 'b-*')
plt.show()
plt.savefig("linear data example.jpg")

# %%
# Creating datframe of both the array to build a linear model.

data = {"Area":area, "Price":price}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Area  Price
# 0    552     34
# 1    553     37
# 2    562     37
# 3    562     39
# 4    566     39
# 5    602     40
# 6    602     41
# 7    611     43
# 8    625     45
# 9    631     45
# 10   634     45
# 11   636     48
# 12   643     53
# 13   651     54
# 14   663     54
# 15   680     57
# 16   681     57
# 17   685     58
# 18   689     59
# 19   693     62
# 20   698     64
# 21   711     64
# 22   715     65
# 23   726     67
# 24   750     68
# 25   756     68
# 26   767     71
# 27   775     74
# 28   789     75
# 29   822     77
# 30   832     79
# 31   852     83
# 32   855     91
# 33   863     91
# 34   863     92
# 35   864     93
# 36   879     94
# 37   881     94
# 38   883     95
# 39   898     97

# %%
# Dividing column in x and y

X = df.drop("Price", axis = 1)
y = df["Price"]

# %%
X.head(3)
# Out:
#    Area
# 0   552
# 1   553
# 2   562

# %%
y.head(3)
# Out:
# 0    34
# 1    37
# 2    37
# Name: Price, dtype: int32

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Checking prediction for the linear model

model.predict([[650]])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([51.68324498])

# %%
model.predict([[1200]])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([149.80124883])

# %%
# predicting x values to get a best fitted line.

y_pred = model.predict(X)

# %%
# %matplotlib inline
plt.title("Area vs Price")
plt.xlabel("Area in SqFt")
plt.ylabel("Price in Lakh")
plt.scatter(area, price, marker="*", c="g")
plt.plot(area, price, 'r--')
plt.plot(area, y_pred, 'b-')
plt.legend(["Actual Points", "Actual Line", "Best Fit Line"])
plt.show()

# %%
coef = model.coef_  # slope=m
intercept = model.intercept_   # intercept=c

# %%
print("Coefficient of x is",coef)
print("Intercept of y is",intercept)
# Out:
# Coefficient of x is [0.17839637]
# Intercept of y is -64.27439593446076

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y, y_pred)
r2
# Out:
# 0.9842852116008093
